# %% [markdown]
# <a href="https://colab.research.google.com/github/tarun1208/AgenticAI/blob/main/Agent_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-genai

# %%
from google import genai
from google.genai import types

# %%
client = genai.Client(api_key='AIzaSyC4SP3Gjdc936Dn0ILSXys1ekMb4x3Ayoo')

# %%
client.models

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Why is the sky blue?')

print(response.text)
# Out:
# The sky appears blue due to a phenomenon called **Rayleigh scattering**. Here's a breakdown:
#
# 1.  **Sunlight is White Light:** What we perceive as white sunlight is actually composed of all the colors of the rainbow (red, orange, yellow, green, blue, indigo, violet). Each of these colors has a different **wavelength** – red has the longest wavelength, and violet/blue have the shortest wavelengths.
#
# 2.  **Earth's Atmosphere:** Our atmosphere is made up of tiny gas molecules, primarily nitrogen (about 78%) and oxygen (about 21%), along with other trace gases and particles. These molecules are much smaller than the wavelengths of visible light.
#
# 3.  **The Scattering Process:**
#     *   When sunlight enters the Earth's atmosphere, it collides with these tiny gas molecules.
#     *   Instead of light passing straight through, it gets **scattered** in all directions.
# ...

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='content: you are helpful chat assistant from our college "Vishnu Institute of Technology" Help out Students. Question:')
#instruction Prompting
print(response.text)
# Out:
# Hello there, future innovators and bright minds of **Vishnu Institute of Technology**!
#
# I'm your dedicated AI chat assistant, designed specifically to help out students like you navigate college life with ease. Think of me as your go-to guide for everything Vishnu – whether you need information on academic programs, campus facilities, upcoming events, club activities, exam schedules, administrative procedures, or even just some friendly advice on settling in.
#
# My aim is to make your experience at our college as smooth, informed, and enriching as possible.
#
# So, don't hold back! I'm here to provide quick, accurate, and helpful answers.
#
# **What's your question today? How can I assist you in making the most of your time at Vishnu Institute of Technology?**

# %%
context = {"Name":"Tarun", "Branch":"CSE", "Section":"C", "College":"Vishnu Institue of Technology","CGPA":"8.46","Year":"3rd"}

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=f"here is the context:{context} your question:Give me the section of student")
print(response.text)
# Out:
# The section of the student is C.

# %% [markdown]
# **Pros**
# .easy
# .Fast
#
# **CONS**
# .Costly due to usage of more Tokens
# . More Context == More tokens
