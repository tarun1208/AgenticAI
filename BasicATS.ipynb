# %% [markdown]
# <a href="https://colab.research.google.com/github/tarun1208/GenAI_AgenticAI/blob/main/BasicATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyPDF2

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
  extracted_text=""

  with open(pdf_path,'rb') as file:
    reader=PyPDF2.PdfReader(file)

    for page in reader.pages:
      page_text = page.extract_text()
      if page_text:
        extracted_text+=page.extract_text()

  return extracted_text

# %%
tarun = extract_text_from_pdf('/content/ML_Resume.pdf')
print(tarun)
# Out:
# Nunna Tarun Sri Venkata Sai
# Bhimavaram, India|tarunsrivenkatasai@gmail.com|+91 9553691664
# linkedin.com/in/TarunSriVenkataSai|github.com/tarun1208
# Professional Summary
# Computer Science student with strong proficiency inMachine Learning. Consistently delivers measurable
# outcomes by improving data asset quality, performance, and reliability, including projects that achieved a12%
# increase in model efficacy and a10%reduction in prediction error.
# Technical Skills
# Languages:Java, Python, JavaScript, R
# Frameworks/Tech:Firebase, TensorFlow, Scikit-learn, Pandas, Matplotlib, XGBoost
# Tools:Jupyter Notebook, Colab Notebook, Git, GitHub, VS Code
# Core Competencies:Data Analysis, Predictive Modeling, Feature Engineering, Project Management, Exploratory
# Data Analysis (EDA), Model Evaluation
# Experience
# Machine Learning WorkshopMar 2024 – Jun 2024
# Exploratory Data Analysis
# ...

# %%
from google import genai
client = genai.Client(api_key="AIzaSyDabrDzoSKHcan9vNWpXf7CdopGEbC5e4k")

# %%
response = client.models.generate_content(
        model = "gemini-2.5-flash",
        contents = (f'here is my context{tarun}, question: give rating for my response')
)

print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=10>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""This is a very strong resume for a Computer Science student with an ML focus! You've done an excellent job of quantifying your achievements and showcasing relevant skills.
#
# **Overall Rating: 8.5/10**
#
# Here's a detailed breakdown with suggestions for improvement:
#
# ---
#
# ### Strengths:
#
# 1.  **Quantifiable Achievements:** You consistently use numbers and percentages (12% efficacy, 10% error reduction, R2 of 0.85/0.89, 80% user interest, 75% accurate predictions). This is *crucial* for standing out and demonstrating impact.
# 2.  **Strong Professional Summary:** It's concise, highlights your ML proficiency, and immediately presents measurable outcomes.
# 3.  **Relevant Technical Skills:** Your skills section is well-aligned with Machine Learning roles, covering languages, frameworks, tools, and core competencies.
# ...

# %%
def resume_parser(input):
  prompt=f"""
  your resume parser
  Extract:
  -Executive Summary
  -Skills
  -Education
  -Tools & Techonolgies
  -Experience Summaryg

  Resume:
  {input}
  return in bullet points
  """
  response = client.models.generate_content(
          model = "gemini-2.5-flash",
          contents = prompt
  )
  return response.text

result = resume_parser(tarun)
print(result)
# Out:
# Here's the extracted information in bullet points:
#
# *   **Executive Summary**
#     *   Computer Science student with strong proficiency in Machine Learning.
#     *   Consistently delivers measurable outcomes by improving data asset quality, performance, and reliability.
#     *   Projects achieved a 12% increase in model efficacy and a 10% reduction in prediction error.
#
# *   **Skills**
#     *   **Languages:** Java, Python, JavaScript, R
#     *   **Frameworks/Libraries:** Firebase, TensorFlow, Scikit-learn, Pandas, Matplotlib, XGBoost
#     *   **Core Competencies:** Data Analysis, Predictive Modeling, Feature Engineering, Project Management, Exploratory Data Analysis (EDA), Model Evaluation
#
# *   **Education**
#     *   **Vishnu Institute of Technology, Bhimavaram:** B.Tech in Computer Science and Engineering (2023 – 2027, CGPA: 8.34/10)
#     *   **Tirumala Junior Kalasala, Katheru:** Intermediate (2021 – 2023, Percentage: 95.6%)
# ...

# %%
def jobDescription(output):
  prompt=f"""
  your jobDescription parser
  Extract:
   -Skills
   -Responsebilities
   -Qualifications

   Job Description:
   {output}
  return in bullet points
  """

  response = client.models.generate_content(
      model = "gemini-2.5-flash",
      contents = prompt
  )
  print(response.text)
  return response

result = jobDescription(tarun)
print(result)
# Out:
# Here's the parsed information from the job description:
#
# ### Skills
#
# *   **Languages:** Java, Python, JavaScript, R
# *   **Frameworks/Tech:** Firebase, TensorFlow, Scikit-learn, Pandas, Matplotlib, XGBoost, NumPy
# *   **Tools:** Jupyter Notebook, Colab Notebook, Git, GitHub, VS Code
# *   **Core Competencies:**
#     *   Data Analysis
#     *   Predictive Modeling (Regression, Classification)
#     *   Feature Engineering
#     *   Project Management
#     *   Exploratory Data Analysis (EDA)
#     *   Model Evaluation
#     *   Parameter Tuning
#     *   Hyperparameter Tuning (Grid Search)
#     *   Model Interpretation (Feature Importance, Residual Analysis)
#     *   Machine Learning
#     *   AI-driven Web Platform Development
#     *   Logistics Analysis
#     *   Front-end Development
#
# ### Responsibilities
#
# *   Built and evaluated predictive models on 5+ datasets for classification tasks using Python/Scikit-learn.
# ...
